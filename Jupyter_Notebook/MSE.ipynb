# %%
import numpy as np

A = np.random.random((50, 2))
print(A, '\n')
B = np.random.random ((50, 2))
print(B)
# Out:
# [[ 0.87411684  0.17621614]
#  [ 0.68343713  0.19469541]
#  [ 0.329727    0.55263528]
#  [ 0.44042477  0.26540999]
#  [ 0.58483274  0.23762355]
#  [ 0.75909069  0.48891025]
#  [ 0.28285163  0.2845531 ]
#  [ 0.53678823  0.08191446]
#  [ 0.10083402  0.17509605]
#  [ 0.42905856  0.83270006]
#  [ 0.89724775  0.35453444]
#  [ 0.83547272  0.68580905]
#  [ 0.11373029  0.7133799 ]
#  [ 0.12648143  0.66898055]
#  [ 0.75880145  0.31894489]
#  [ 0.8508314   0.97829149]
#  [ 0.40186414  0.50034425]
#  [ 0.16996127  0.16963902]
#  [ 0.04961368  0.95911451]
#  [ 0.10902623  0.22023416]
#  [ 0.23581666  0.46076725]
#  [ 0.46086782  0.80774891]
#  [ 0.07203695  0.02884529]
#  [ 0.41836049  0.12712691]
#  [ 0.04253578  0.60273788]
#  [ 0.27710473  0.56321831]
#  [ 0.13512872  0.85362266]
#  [ 0.33784122  0.52594003]
#  [ 0.78778724  0.38893363]
#  [ 0.92977169  0.01627688]
#  [ 0.63567365  0.31033591]
#  [ 0.47923697  0.48812298]
#  [ 0.44513841  0.78425047]
#  [ 0.19259491  0.82374024]
# ...

# %%
MSE = []
for i in range(len(A)):
    MSE.append((A[i, 0] - B[i, 0])**2 + (A[i, 1] - B[i, 1])**2) 
    
print(np.mean(MSE))
# Out:
# 0.332597578504
